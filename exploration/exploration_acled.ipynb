# %% [markdown]
# # Exploring ACLED dataset

# %%
import pandas as pd
df = pd.read_csv("acled_20211224.csv")

# %%
print(len(df.columns))
print(df.size)
df.iloc[:, 1:10].head()
# Out:
# 31
# 38207314
#    iso event_id_cnty  event_id_no_cnty        event_date  year  \
# 0  710      SAF15902           15902.0  26 November 2021  2021
# 1  364      IRN11785           11785.0  26 November 2021  2021
# 2  364      IRN11796           11796.0  26 November 2021  2021
# 3  364      IRN11798           11798.0  26 November 2021  2021
# 4  275      PSE12790           12790.0  26 November 2021  2021
#
#    time_precision                  event_type         sub_event_type  \
# 0               2  Violence against civilians        Sexual violence
# 1               1                    Protests       Peaceful protest
# 2               1                    Protests       Peaceful protest
# 3               1                       Riots  Violent demonstration
# 4               1                       Riots           Mob violence
#
#                                   actor1
# 0  Police Forces of South Africa (1994-)
# 1                      Protesters (Iran)
# ...

# %%
df.iloc[:, 10:20].head()
# Out:
#                assoc_actor_1  inter1                             actor2  \
# 0                        NaN       1           Civilians (South Africa)
# 1               Women (Iran)       6                                NaN
# 2                        NaN       6                                NaN
# 3             Farmers (Iran)       5      Police Forces of Iran (1989-)
# 4  Refugees/IDPs (Palestine)       5  Military Forces of Israel (2021-)
#
#                                     assoc_actor_2  inter2  interaction  \
# 0  Women (South Africa); Prisoners (South Africa)       7           17
# 1                                             NaN       0           60
# 2                                             NaN       0           60
# 3                                             NaN       1           15
# 4                                             NaN       8           58
#
#             region       country         admin1       admin2
# ...

# %%
df.iloc[:, 20:].head()
# Out:
#       admin3          location  latitude  longitude  geo_precision  \
# 0  Maphumulo         Maphumulo  -29.1500    31.0666              1
# 1    Central          Sanandaj   35.3150    46.9988              1
# 2    Central       Khorramabad   33.4878    48.3558              1
# 3    Central           Isfahan   32.6525    51.6746              1
# 4        NaN  Mukhayyam Ayidah   31.7195    35.1986              1
#
#                                               source     source_scale  \
# 0                              News24 (South Africa)         National
# 1  Free Union of Iranian Workers; Kurdistan Human...            Other
# 2                         Eteraze Bazar; Iran Kargar        New media
# 3  Iran International; Radio Farda; Iran Kargar; ...  Other-New media
# 4  Palestine News and Information Agency; Dunia A...         National
#
#                                                notes  fatalities   timestamp  \
# ...

# %%
len(df["country"].unique())
# Out:
# 207

# %%
len(df["region"].unique())
# Out:
# 15

# %%
df["region"].unique()
# Out:
# array(['Southern Africa', 'Middle East', 'South America',
#        'Central America', 'North America', 'Caribbean', 'Western Africa',
#        'Eastern Africa', 'Northern Africa', 'Middle Africa', 'East Asia',
#        'Southeast Asia', 'South Asia', 'Europe',
#        'Caucasus and Central Asia'], dtype=object)

# %%
aux = df[df['region'].str.contains("Asia|Middle East")]
aux["region"].unique()
# Out:
# array(['Middle East', 'East Asia', 'Southeast Asia', 'South Asia',
#        'Caucasus and Central Asia'], dtype=object)

# %%
len(aux["country"].unique())
# Out:
# 48

# %%
aux.to_csv("acled_asia_2021.csv", index=False)

# %%
dg = pd.read_csv("acled_asia_2021.csv")

# %%
dg.head()
# Out:
#    data_id  iso event_id_cnty  event_id_no_cnty        event_date  year  \
# 0  8658794  364      IRN11785           11785.0  26 November 2021  2021
# 1  8658804  364      IRN11796           11796.0  26 November 2021  2021
# 2  8658806  364      IRN11798           11798.0  26 November 2021  2021
# 3  8658881  275      PSE12790           12790.0  26 November 2021  2021
# 4  8658900  275      PSE12826           12826.0  26 November 2021  2021
#
#    time_precision event_type         sub_event_type               actor1  ...  \
# 0               1   Protests       Peaceful protest    Protesters (Iran)  ...
# 1               1   Protests       Peaceful protest    Protesters (Iran)  ...
# 2               1      Riots  Violent demonstration       Rioters (Iran)  ...
# 3               1      Riots           Mob violence  Rioters (Palestine)  ...
# 4               1      Riots  Violent demonstration  Rioters (Palestine)  ...
#
#            location  latitude longitude geo_precision  \
# ...

# %%
aux2 = dg[["data_id", "event_date", "iso3", "event_type", "fatalities"]]
aux2.to_csv("acled_asia_2021_subset.csv", index=False)
